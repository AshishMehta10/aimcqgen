# %%
import os
import json
import pandas as pd
import traceback

# %%
from langchain_openai import ChatOpenAI

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
key=os.getenv("OPENAI_API_KEY")

# %%
print(key)
# Out:
# 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
